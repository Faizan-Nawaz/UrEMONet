# %%
# !pip install openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 45.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=b52407cae8284842e84df13148ded0c35c381856854a98245d6121f73b3ef7a0
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
pip install faster-whisper
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.0/39.0 MB 36.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 86.7 MB/s eta 0:00:00
# ...

# %%
import torch
import gc

# Clear memory
gc.collect()
torch.cuda.empty_cache()

# %%
# !cp -r "/content/drive/MyDrive/Audio_data" "/content/audio"

# %%
from faster_whisper import WhisperModel
import os
import csv
from tqdm import tqdm

# --- 1. CONFIG ---
model_size = "small"
model = WhisperModel(model_size, device="cuda", compute_type="float16")

audio_dir = r"/content/audio"
csv_file = "transcriptions.csv"

audio_files = [f for f in os.listdir(audio_dir) if f.endswith((".mp3", ".wav"))]

# --- 2. LIVE PROCESSING ---
print(f"Total Files: {len(audio_files)}")

# 'a' (append)
with open(csv_file, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(["Audio Link", "Transcription"])


    for filename in tqdm(audio_files, desc="Processing Urdu Audio"):
        path = os.path.join(audio_dir, filename)
        try:
            segments, _ = model.transcribe(path, beam_size=1, language="ur")
            text = "".join([s.text for s in segments]).strip()


            writer.writerow([filename, text])
            f.flush() # Force save to disk

        except Exception as e:
            print(f"\nError in {filename}: {e}")

print(f"\nDone! Check File: {csv_file}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Total Files: 8588
# Processing Urdu Audio: 100%|██████████| 8588/8588 [1:18:51<00:00,  1.82it/s]
# Done! Check File: transcriptions.csv

# %%
# !cp -r "/content/transcriptions.csv" "/content/drive/MyDrive/transcriptions.csv"
